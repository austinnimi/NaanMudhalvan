# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("USA_Housing.csv")

# %%
data
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                             4.09     23086.800503  1.059034e+06
# 1                             3.09     40173.072174  1.505891e+06
# 2                             5.13     36882.159400  1.058988e+06
# 3                             3.26     34310.242831  1.260617e+06
# 4                             4.23     26354.109472  6.309435e+05
# ...                            ...              ...           ...
# 4995                          3.46     22837.361035  1.060194e+06
# 4996                          4.02     25616.115489  1.482618e+06
# 4997                          2.13     33266.145490  1.030730e+06
# 4998                          5.44     42625.620156  1.198657e+06
# 4999                          4.07     46501.283803  1.298950e+06
#
#                                                 Address
# 0     208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1     188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2     9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3                             USS Barnett\nFPO AP 44820
# 4                            USNS Raymond\nFPO AE 09386
# ...                                                 ...
# 4995                   USNS Williams\nFPO AP 30153-7653
# 4996              PSC 9258, Box 8489\nAPO AA 42991-3352
# 4997  4215 Tracy Garden Suite 076\nJoshualand, VA 01...
# 4998                          USS Wallace\nFPO AE 73316
# 4999  37778 George Ridges Apt. 509\nEast Holly, NV 2...
#
# [5000 rows x 7 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
data.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Avg. Area Income'}>,
#         <AxesSubplot:title={'center':'Avg. Area House Age'}>],
#        [<AxesSubplot:title={'center':'Avg. Area Number of Rooms'}>,
#         <AxesSubplot:title={'center':'Avg. Area Number of Bedrooms'}>],
#        [<AxesSubplot:title={'center':'Area Population'}>,
#         <AxesSubplot:title={'center':'Price'}>]], dtype=object)

# %%
from sklearn.model_selection import train_test_split
X = data.drop(["Price"],axis = 1)
Y = data["Price"]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.2)

# %%
train_data = X_train.join(Y_train)

# %%
train_data
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 3318      77287.173219             5.600924                   5.546760
# 127       72138.870482             7.163641                   8.485778
# 4787      59048.752191             5.847588                   6.585168
# 2174      63335.794906             6.295120                   6.308114
# 1697      60826.605956             6.383383                   6.255855
# ...                ...                  ...                        ...
# 2245      64405.649441             8.005413                   7.879408
# 3331      68056.302261             7.585253                   7.362407
# 2511      62184.539375             4.925758                   7.427689
# 2855      66835.220118             6.525598                   5.228439
# 2422      54236.696249             5.643911                   8.473199
#
#       Avg. Area Number of Bedrooms  Area Population  \
# 3318                          4.50     35041.734758
# 127                           5.45     35799.638274
# 4787                          4.46     14520.605321
# 2174                          3.44     35469.028665
# 1697                          3.18     36892.623301
# ...                            ...              ...
# 2245                          6.12     42611.539703
# 3331                          6.00     31852.043380
# 2511                          6.22     26008.309124
# 2855                          3.16     23523.601978
# 2422                          3.27     65857.933322
#
#                                                 Address         Price
# 3318    2323 Jonathon Lodge\nLake Ashley, WV 40500-8885  1.144711e+06
# 127            156 Conner Lane\nEast Brittany, MI 26733  1.629984e+06
# 4787     68008 Taylor Streets\nGrayburgh, CT 95202-6505  5.628395e+05
# 2174  524 Patrick Heights Suite 522\nLewisport, VA 8...  1.172515e+06
# 1697  2012 Jamie Stream Suite 731\nSouth Amandahaven...  1.127874e+06
# ...                                                 ...           ...
# 2245             65018 Mcdonald Dam\nHineston, FL 55892  1.420979e+06
# 3331  89265 Robert Haven Apt. 492\nSmithburgh, FM 58...  1.470427e+06
# 2511  62280 Taylor Drive Apt. 014\nSarahburgh, GU 68004  8.730483e+05
# 2855  738 David Courts Suite 621\nBrittanymouth, ND ...  7.924495e+05
# 2422          20665 David Well\nPhillipsshire, WV 17695  1.372969e+06
#
# [4000 rows x 7 columns]

# %%
train_data.hist(figsize = (15,8))
# Out:
# array([[<AxesSubplot:title={'center':'Avg. Area Income'}>,
#         <AxesSubplot:title={'center':'Avg. Area House Age'}>],
#        [<AxesSubplot:title={'center':'Avg. Area Number of Rooms'}>,
#         <AxesSubplot:title={'center':'Avg. Area Number of Bedrooms'}>],
#        [<AxesSubplot:title={'center':'Area Population'}>,
#         <AxesSubplot:title={'center':'Price'}>]], dtype=object)

# %%
plt.figure(figsize = (15,8))
sns.heatmap(train_data.corr(), annot = True, cmap = "YlGnBu")
# Out:
# <AxesSubplot:>

# %%
train_data."Avg. Area Number of Rooms".values_count()
# Out:
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_588\4184056256.py", line 1
#     train_data."Avg. Area Number of Rooms".values_count()
#                ^
# SyntaxError: invalid syntax

# %%
train_data.rename(columns = {"Avg. Area Number of Rooms" : "Avg_Area_Number_of_Rooms"}, inplace = True)

# %%
train_data
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg_Area_Number_of_Rooms  \
# 3318      77287.173219             5.600924                  5.546760
# 127       72138.870482             7.163641                  8.485778
# 4787      59048.752191             5.847588                  6.585168
# 2174      63335.794906             6.295120                  6.308114
# 1697      60826.605956             6.383383                  6.255855
# ...                ...                  ...                       ...
# 2245      64405.649441             8.005413                  7.879408
# 3331      68056.302261             7.585253                  7.362407
# 2511      62184.539375             4.925758                  7.427689
# 2855      66835.220118             6.525598                  5.228439
# 2422      54236.696249             5.643911                  8.473199
#
#       Avg. Area Number of Bedrooms  Area Population  \
# 3318                          4.50     35041.734758
# 127                           5.45     35799.638274
# 4787                          4.46     14520.605321
# 2174                          3.44     35469.028665
# 1697                          3.18     36892.623301
# ...                            ...              ...
# 2245                          6.12     42611.539703
# 3331                          6.00     31852.043380
# 2511                          6.22     26008.309124
# 2855                          3.16     23523.601978
# 2422                          3.27     65857.933322
#
#                                                 Address         Price
# 3318    2323 Jonathon Lodge\nLake Ashley, WV 40500-8885  1.144711e+06
# 127            156 Conner Lane\nEast Brittany, MI 26733  1.629984e+06
# 4787     68008 Taylor Streets\nGrayburgh, CT 95202-6505  5.628395e+05
# 2174  524 Patrick Heights Suite 522\nLewisport, VA 8...  1.172515e+06
# 1697  2012 Jamie Stream Suite 731\nSouth Amandahaven...  1.127874e+06
# ...                                                 ...           ...
# 2245             65018 Mcdonald Dam\nHineston, FL 55892  1.420979e+06
# 3331  89265 Robert Haven Apt. 492\nSmithburgh, FM 58...  1.470427e+06
# 2511  62280 Taylor Drive Apt. 014\nSarahburgh, GU 68004  8.730483e+05
# 2855  738 David Courts Suite 621\nBrittanymouth, ND ...  7.924495e+05
# 2422          20665 David Well\nPhillipsshire, WV 17695  1.372969e+06
#
# [4000 rows x 7 columns]

# %%
train_data.Avg_Area_Number_of_Rooms.mean()
# Out:
# 6.977204682663902

# %%
plt.figure(figsize = (15,8))
sns.scatterplot(x = "Avg. Area Income", y = "Avg. Area House Age" , data = train_data, hue = "Price", palette = "coolwarm")
# Out:
# <AxesSubplot:xlabel='Avg. Area Income', ylabel='Avg. Area House Age'>

# %%
Y_train= Y_train.round(decimals = 2)
Y_train
# Out:
# 3318    1144711.18
# 127     1629983.85
# 4787     562839.47
# 2174    1172514.72
# 1697    1127873.58
#            ...
# 2245    1420979.18
# 3331    1470427.38
# 2511     873048.32
# 2855     792449.54
# 2422    1372969.31
# Name: Price, Length: 4000, dtype: float64

# %%
train_data = train_data.Price.round(decimals = 2)

# %%
train_data
# Out:
# 3318    1144711.18
# 127     1629983.85
# 4787     562839.47
# 2174    1172514.72
# 1697    1127873.58
#            ...
# 2245    1420979.18
# 3331    1470427.38
# 2511     873048.32
# 2855     792449.54
# 2422    1372969.31
# Name: Price, Length: 4000, dtype: float64

# %%
train_data = X_train.join(Y_train)

# %%
Y_train
# Out:
# 3318    1144711.18
# 127     1629983.85
# 4787     562839.47
# 2174    1172514.72
# 1697    1127873.58
#            ...
# 2245    1420979.18
# 3331    1470427.38
# 2511     873048.32
# 2855     792449.54
# 2422    1372969.31
# Name: Price, Length: 4000, dtype: float64

# %%
train_data
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 3318      77287.173219             5.600924                   5.546760
# 127       72138.870482             7.163641                   8.485778
# 4787      59048.752191             5.847588                   6.585168
# 2174      63335.794906             6.295120                   6.308114
# 1697      60826.605956             6.383383                   6.255855
# ...                ...                  ...                        ...
# 2245      64405.649441             8.005413                   7.879408
# 3331      68056.302261             7.585253                   7.362407
# 2511      62184.539375             4.925758                   7.427689
# 2855      66835.220118             6.525598                   5.228439
# 2422      54236.696249             5.643911                   8.473199
#
#       Avg. Area Number of Bedrooms  Area Population  \
# 3318                          4.50     35041.734758
# 127                           5.45     35799.638274
# 4787                          4.46     14520.605321
# 2174                          3.44     35469.028665
# 1697                          3.18     36892.623301
# ...                            ...              ...
# 2245                          6.12     42611.539703
# 3331                          6.00     31852.043380
# 2511                          6.22     26008.309124
# 2855                          3.16     23523.601978
# 2422                          3.27     65857.933322
#
#                                                 Address       Price
# 3318    2323 Jonathon Lodge\nLake Ashley, WV 40500-8885  1144711.18
# 127            156 Conner Lane\nEast Brittany, MI 26733  1629983.85
# 4787     68008 Taylor Streets\nGrayburgh, CT 95202-6505   562839.47
# 2174  524 Patrick Heights Suite 522\nLewisport, VA 8...  1172514.72
# 1697  2012 Jamie Stream Suite 731\nSouth Amandahaven...  1127873.58
# ...                                                 ...         ...
# 2245             65018 Mcdonald Dam\nHineston, FL 55892  1420979.18
# 3331  89265 Robert Haven Apt. 492\nSmithburgh, FM 58...  1470427.38
# 2511  62280 Taylor Drive Apt. 014\nSarahburgh, GU 68004   873048.32
# 2855  738 David Courts Suite 621\nBrittanymouth, ND ...   792449.54
# 2422          20665 David Well\nPhillipsshire, WV 17695  1372969.31
#
# [4000 rows x 7 columns]

# %%
plt.figure(figsize = (15,8))
sns.scatterplot(x = "Avg. Area Income", y = "Avg. Area House Age" , data = train_data, hue = "Price", palette = "coolwarm")
# Out:
# <AxesSubplot:xlabel='Avg. Area Income', ylabel='Avg. Area House Age'>

# %%
plt.figure(figsize = (15,8))
sns.scatterplot(x = "Avg. Area Income", y = "Price" , data = train_data, hue = "Price", palette = "coolwarm")
# Out:
# <AxesSubplot:xlabel='Avg. Area Income', ylabel='Price'>

# %%
#Feature Engineering and Model Building

train_data["bedroom_area_ratio"] = train_data["Avg. Area Number of Bedrooms"] / train_data["Avg. Area Number of Rooms"]

# %%
plt.figure(figsize = (15,8))
sns.heatmap(train_data.corr(), annot = True, cmap = "YlGnBu")
# Out:
# <AxesSubplot:>

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

'''train_data_address = train_data["Address"]
train_data = train_data.drop(["Address"],axis = 1)'''

x_train,y_train = train_data.drop(["Price"], axis = 1), train_data["Price"]
x_train_s = scaler.fit_transform(x_train)

reg = LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
test_data = X_test.join(Y_test)
test_data_address = test_data["Address"]
test_data = test_data.drop(["Address"],axis = 1)
test_data["bedroom_area_ratio"] = test_data["Avg. Area Number of Bedrooms"] / test_data["Avg. Area Number of Rooms"]

# %%
x_test,y_test = test_data.drop(["Price"], axis = 1), test_data["Price"]

# %%
x_test_s = scaler.transform(x_test)

# %%
reg.score(x_test,y_test)
# Out:
# 0.9163355156419327

# %%
reg.score(x_test_s,y_test)
# Out:
# 0.9163355156419459

# %%
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()

forest.fit(x_train_s,y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(x_test_s, y_test)
# Out:
# 0.8844666295835167

# %%
from sklearn.model_selection import GridSearchCV

forest = RandomForestRegressor()

param_grid = {
    "n_estimators": [100, 200, 300],
    "max_features": [6]
}

grid_search = GridSearchCV(forest, param_grid, cv=5,scoring = "neg_mean_squared_error",
                           return_train_score = True)

grid_search.fit(x_train_s,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': [6], 'n_estimators': [100, 200, 300]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
best_forest = grid_search.best_estimator_

# %%
best_forest.score(x_test_s,y_test)
# Out:
# 0.8855340019730495
